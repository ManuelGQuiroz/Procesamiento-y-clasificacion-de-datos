# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
import os

# %% [markdown]
# ### Loading the Dataset

# %%
google=pd.read_csv('/content/drive/MyDrive/Classroom/Procesamiento y clasificacion de datos/googleplaystore.csv')

# %% [markdown]
# #### First 10 values

# %%
google.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
google.shape
# Out:
# (10841, 13)

# %% [markdown]
# #### Print the name of columns

# %%
google.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# #### Check for NULL Values

# %%
google.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# #### Check unique values

# %%
google.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %% [markdown]
# #### Check for Duplicate values

# %%
google.duplicated().sum()
# Out:
# 483

# %% [markdown]
# Duplicate values present.

# %% [markdown]
# #### Make a copy of the dataset

# %%
df = google.copy()

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# #### Drop NULL values

# %%
df=df.dropna()
df.shape
# Out:
# (9360, 13)

# %% [markdown]
# #### Print first 10 values

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# #### Convert Date Time format

# %%
df["Last Updated"] = pd.to_datetime(df['Last Updated'])
df['day_added'] = df['Last Updated'].dt.day
df['year_added'] = df['Last Updated'].dt.year
df['month_added']=df['Last Updated'].dt.month
df['year_added'].astype(int);
df['day_added'].astype(int);

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Type: Free / Paid

# %%
sns.countplot(google['Type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type')

# %% [markdown]
# ### Content Rating

# %%
sns.countplot(google['Content Rating'])
sns.countplot(google['Content Rating']).set_xticklabels(sns.countplot(google['Content Rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Rating')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rating')

# %% [markdown]
# ### Relation between Type and Content Rating

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Content Rating',hue='Type',data=google)
plt.title('Relation between Type and Content Rating')
plt.show()

# %% [markdown]
# ### Pie-chart for the Type: Free and Paid

# %%
labels = ['Free', 'Paid', 'None']
size = google['Type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0.1, 0.1, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# ### Pie-chart for Content Rating

# %%
google['Content Rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud

# %% [markdown]
# ## Genres

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Genres))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('Genres.png')
plt.show()

# %% [markdown]
# ## Category

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Category))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('Category.png')
plt.show()

# %% [markdown]
# ## Size

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Size))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('Size.png')
plt.show()

# %% [markdown]
# ## App

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df['App']))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('App.png')
plt.show()

# %% [markdown]
# # Conclusiones
#
#
# Para esta base de datos, podemos concluir que las problematicas son que si se necesita preprocesar mucho la base de datos, en los campos encontramos valores nulos en los cuales es importante tener un valor como lo es el Genero de la aplicación, la calificación que los usuarios asignan a la app. Para el campo de la App si se necesita normalizar ya que hay muchos caracteres especiales que no ayudan para el nombre de la aplicación ya que entrarian en el concepto de caracter basura o en su caso que al momento de abrir la base de datos en formato .xlsx o .csv este lo interpreta como si fuera una formula. En el caso del campo de Tipo hace referencia si es de paga o si es gratis la app solo un registro aparece como nulo, desde mi punto no afecta ya que solo es un registro de 9,000 registros por lo que optaria en eliminarlo. El campo de Current Version tambien se tendria que preprocesar ya que existe un campo fecha en lugar de la version de la aplicación.
